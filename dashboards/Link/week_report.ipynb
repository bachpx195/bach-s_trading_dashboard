# %%
from services.reports.week_report_service import get_day_data_prices

MERCHANDISE_RATE = 'LINKUSDT'
DAYS = 60

data_prices, merchandise_rate_id = get_day_data_prices(MERCHANDISE_RATE, DAYS)
# Out:
# 12:58:41 DEBUG
# _________________________________________log query_________________________________________
# 12:58:41 DEBUG
# SELECT * FROM DailyTradingJournal_development.candlesticks candlesticks INNER JOIN DailyTradingJournal_development.day_analytics ON candlesticks.id = day_analytics.candlestick_id WHERE candlesticks.time_type = 1 AND candlesticks.merchandise_rate_id = 42 ORDER BY candlesticks.date DESC lIMIT 60;
# 12:58:42 DEBUG
# 	                            open   high  close    low     volumn  candlestick_type  range_type  is_inside_day  is_same_btc  continue_type
# 	date
# 	2024-10-16 07:00:00+07:00  11.45  11.47  11.39  11.25   188550.0             -0.52        1.96              0          NaN              0
# 	2024-10-15 07:00:00+07:00  11.29  11.70  11.45  10.93  4806200.0              1.42        7.04              1         22.0              0
# ...
